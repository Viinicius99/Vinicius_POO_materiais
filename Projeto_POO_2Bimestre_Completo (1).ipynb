# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**      VInicius
#
# **Turma:** 2Ati
#
# **Tema Escolhido:**  Requisição de materias escolares

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# 📘 Projeto: Requisição de Materiais Escolares - Vinicius
# Turma: 2ATI
# Autor: Vinicius

# ===================== CLASSES ==========================

class RequisicaoVinicius:
    def __init__(self, solicitante, destino, material, quantidade):
        self.__solicitante = solicitante  # Atributo privado
        self.destino = destino
        self.material = material
        self.quantidade = quantidade

    def exibir_dados_Vinicius(self):
        print(f"\n📦 Requisição:\n- Solicitante: {self.__solicitante}\n- Destino: {self.destino}\n- Material: {self.material}\n- Quantidade: {self.quantidade}")

    def get_solicitante_Vinicius(self):
        return self.__solicitante

    def set_solicitante_Vinicius(self, novo_nome):
        self.__solicitante = novo_nome

    def verificar_material_Vinicius(self):
        materiais_disponiveis = ['caneta', 'lápis', 'papel', 'borracha']
        if self.material.lower() in materiais_disponiveis:
            print("✅ Material disponível no estoque.")
        else:
            print("⚠️ Material pode estar indisponível.")

class RequisicaoUrgenteVinicius(RequisicaoVinicius):
    def __init__(self, solicitante, destino, material, quantidade, prioridade):
        super().__init__(solicitante, destino, material, quantidade)
        self.prioridade = prioridade

    def marcar_como_urgente_Vinicius(self):
        if self.prioridade:
            print("🚨 Requisição marcada como URGENTE!")
        else:
            print("⏳ Requisição padrão.")

    def exibir_dados_Vinicius(self):
        print(f"\n🚨 Requisição URGENTE:\n- Solicitante: {self.get_solicitante_Vinicius()}\n- Destino: {self.destino}\n- Material: {self.material}\n- Quantidade: {self.quantidade}\n- Prioridade: {'Alta' if self.prioridade else 'Baixa'}")

# ===================== DADOS E FUNÇÕES ==========================
usuarios_vinicius = {}  # Armazenamento de usuários
requisoes_vinicius = []  # Lista de requisições

def cadastrar_usuario_Vinicius():
    print("\n👤 Cadastro de Usuário")
    while True:
        nome = input("Escolha um nome de usuário: ")
        if nome in usuarios_vinicius:
            print("❌ Usuário já existe. Tente outro.")
        else:
            break

    senha = input("Escolha uma senha: ")
    tipo = ""
    while tipo not in ["operador", "cliente"]:
        tipo = input("Tipo de usuário (operador / cliente): ").lower()
        if tipo not in ["operador", "cliente"]:
            print("⚠️ Tipo inválido.")

    usuarios_vinicius[nome] = {"senha": senha, "tipo": tipo}
    print(f"✅ Usuário '{nome}' cadastrado como '{tipo}'.")

def login_Vinicius():
    print("\n🔐 Login")
    usuario = input("Usuário: ")
    senha = input("Senha: ")

    if usuario in usuarios_vinicius and usuarios_vinicius[usuario]["senha"] == senha:
        print(f"✅ Login bem-sucedido! Bem-vindo, {usuario}.")
        return usuarios_vinicius[usuario]["tipo"]
    else:
        print("❌ Usuário ou senha incorretos.")
        return None

def adicionar_requisicao_Vinicius():
    print("\n➕ Nova Requisição")
    solicitante = input("Nome do solicitante: ")
    destino = input("Destino: ")
    material = input("Material: ")

    while True:
        try:
            quantidade = int(input("Quantidade: "))
            if quantidade <= 0:
                print("⚠️ Quantidade deve ser maior que 0.")
                continue
            break
        except ValueError:
            print("❌ Digite um número válido.")

    prioridade = input("É urgente? (s/n): ").lower() == 's'

    if prioridade:
        req = RequisicaoUrgenteVinicius(solicitante, destino, material, quantidade, True)
    else:
        req = RequisicaoVinicius(solicitante, destino, material, quantidade)

    requisoes_vinicius.append(req)
    print("✅ Requisição adicionada com sucesso!")
    req.exibir_dados_Vinicius()

def listar_requisicoes_Vinicius():
    print("\n📋 Lista de Requisições")
    if not requisoes_vinicius:
        print("📭 Nenhuma requisição registrada.")
        return

    for i, req in enumerate(requisoes_vinicius):
        print(f"\n🔹 Requisição #{i + 1}")
        req.exibir_dados_Vinicius()

def excluir_requisicao_Vinicius():
    listar_requisicoes_Vinicius()
    try:
        index = int(input("Número da requisição a excluir: ")) - 1
        if 0 <= index < len(requisoes_vinicius):
            del requisoes_vinicius[index]
            print("🗑️ Requisição excluída.")
        else:
            print("❌ Índice inválido.")
    except ValueError:
        print("❌ Entrada inválida.")

def editar_requisicao_Vinicius():
    listar_requisicoes_Vinicius()
    try:
        index = int(input("Número da requisição a editar: ")) - 1
        if 0 <= index < len(requisoes_vinicius):
            nova_quantidade = int(input("Nova quantidade: "))
            requisoes_vinicius[index].quantidade = nova_quantidade
            print("✏️ Quantidade atualizada.")
        else:
            print("❌ Número inválido.")
    except ValueError:
        print("❌ Entrada inválida.")

def salvar_requisicoes_Vinicius():
    print(f"💾 Simulando salvamento... Total de requisições: {len(requisoes_vinicius)}")

# ===================== MENU PRINCIPAL ==========================

def menu_principal_Vinicius():
    while True:
        print("\n==== MENU INICIAL ====")
        print("1 - Cadastrar novo usuário")
        print("2 - Fazer login")
        print("0 - Sair")

        escolha = input("Escolha uma opção: ")

        if escolha == "1":
            cadastrar_usuario_Vinicius()
        elif escolha == "2":
            tipo_usuario = login_Vinicius()
            if tipo_usuario:
                menu_usuario_Vinicius(tipo_usuario)
        elif escolha == "0":
            print("👋 Encerrando o sistema.")
            break
        else:
            print("❌ Opção inválida.")

def menu_usuario_Vinicius(tipo_usuario):
    while True:
        print("\n===== MENU DO USUÁRIO =====")
        print("1 - Adicionar Requisição")
        print("2 - Editar Requisição")
        print("3 - Excluir Requisição")
        print("4 - Listar Requisições")
        print("5 - Salvar")
        print("0 - Logout")

        opcao = input("Escolha uma opção: ")

        if opcao == "1":
            if tipo_usuario == "operador":
                adicionar_requisicao_Vinicius()
            else:
                print("🔒 Apenas operadores podem adicionar.")
        elif opcao == "2":
            if tipo_usuario == "operador":
                editar_requisicao_Vinicius()
            else:
                print("🔒 Apenas operadores podem editar.")
        elif opcao == "3":
            if tipo_usuario == "operador":
                excluir_requisicao_Vinicius()
            else:
                print("🔒 Apenas operadores podem excluir.")
        elif opcao == "4":
            listar_requisicoes_Vinicius()
        elif opcao == "5":
            if tipo_usuario == "operador":
                salvar_requisicoes_Vinicius()
            else:
                print("🔒 Apenas operadores podem salvar.")
        elif opcao == "0":
            print("🔙 Saindo do menu do usuário.")
            break
        else:
            print("❌ Opção inválida.")

# ===================== EXECUÇÃO ==========================

if __name__ == "__main__":
    menu_principal_Vinicius()

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 2

def verificar_material_Vinicius(self):
        materiais_disponiveis = ['caneta', 'lápis', 'papel', 'borracha']
        if self.material.lower() in materiais_disponiveis:
            print("✅ Material disponível no estoque.")
        else:
            print("⚠️ Material pode estar indisponível.")

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 3

def get_solicitante_Vinicius(self):
        return self.__solicitante

    def set_solicitante_Vinicius(self, novo_nome):
        self.__solicitante = novo_nome

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 4

class RequisicaoUrgenteVinicius(RequisicaoVinicius):
    def __init__(self, solicitante, destino, material, quantidade, prioridade):
        super().__init__(solicitante, destino, material, quantidade)
        self.prioridade = prioridade  # Novo atributo exclusivo da subclasse

    # Novo método exclusivo
    def marcar_como_urgente_Vinicius(self):
        if self.prioridade:
            print("🚨 Requisição marcada como URGENTE!")
        else:
            print("⏳ Requisição padrão.")

    # Polimorfismo: sobrescrita do método da superclasse
    def exibir_dados_Vinicius(self):
        print(f"\n🚨 Requisição URGENTE:\n- Solicitante: {self.get_solicitante_Vinicius()}\n- Destino: {self.destino}\n- Material: {self.material}\n- Quantidade: {self.quantidade}\n- Prioridade: {'Alta' if self.prioridade else 'Baixa'}")

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 5

# !pip install mysql-connector-python


import mysql.connector
import getpass

# Conexão com o banco de dados
def conectar():
    return mysql.connector.connect(
        host="localhost",
        user="root",
        password="",  # normalmente em branco no XAMPP
        database="escola_vinicius"
    )

# Classe para requisições
class RequisicaoVinicius:
    def __init__(self, solicitante, destino, material, quantidade, prioridade, usuario_id):
        self.solicitante = solicitante
        self.destino = destino
        self.material = material
        self.quantidade = quantidade
        self.prioridade = prioridade
        self.usuario_id = usuario_id

    def salvar_no_banco(self):
        conexao = conectar()
        cursor = conexao.cursor()
        cursor.execute("""
            INSERT INTO requisicoes_vinicius (solicitante, destino, material, quantidade, prioridade, usuario_id)
            VALUES (%s, %s, %s, %s, %s, %s)
        """, (self.solicitante, self.destino, self.material, self.quantidade, self.prioridade, self.usuario_id))
        conexao.commit()
        conexao.close()
        print("✅ Requisição salva com sucesso!")

# Cadastro de usuário
def cadastrar_usuario():
    nome = input("Digite o nome do novo usuário: ")
    senha = getpass.getpass("Digite a senha: ")
    tipo = input("Tipo de usuário (operador/cliente): ").lower()

    conexao = conectar()
    cursor = conexao.cursor()
    try:
        cursor.execute("""
            INSERT INTO usuarios_vinicius (nome, senha, tipo)
            VALUES (%s, %s, %s)
        """, (nome, senha, tipo))
        conexao.commit()
        print("✅ Usuário cadastrado com sucesso!")
    except mysql.connector.errors.IntegrityError:
        print("❌ Nome de usuário já existe.")
    conexao.close()

# Login
def login():
    nome = input("Nome de usuário: ")
    senha = getpass.getpass("Senha: ")

    conexao = conectar()
    cursor = conexao.cursor(dictionary=True)
    cursor.execute("""
        SELECT * FROM usuarios_vinicius WHERE nome = %s AND senha = %s
    """, (nome, senha))
    usuario = cursor.fetchone()
    conexao.close()

    if usuario:
        print(f"\n🔓 Login bem-sucedido como {usuario['tipo']}!\n")
        return usuario
    else:
        print("❌ Usuário ou senha inválidos.")
        return None

# Cadastrar nova requisição
def nova_requisicao(usuario):
    solicitante = input("Solicitante: ")
    destino = input("Destino: ")
    material = input("Material: ")
    quantidade = int(input("Quantidade: "))
    prioridade = input("É urgente? (s/n): ").lower() == 's'

    req = RequisicaoVinicius(solicitante, destino, material, quantidade, prioridade, usuario['id'])
    req.salvar_no_banco()

# Listar requisições
def listar_requisicoes():
    conexao = conectar()
    cursor = conexao.cursor()
    cursor.execute("SELECT * FROM requisicoes_vinicius")
    registros = cursor.fetchall()
    conexao.close()

    if registros:
        print("\n📄 Requisições cadastradas:")
        for r in registros:
            print(f"ID: {r[0]} | Solicitante: {r[1]} | Material: {r[3]} | Quantidade: {r[4]} | Urgente: {'Sim' if r[5] else 'Não'}")
    else:
        print("📭 Nenhuma requisição encontrada.")

# Excluir requisição
def excluir_requisicao():
    listar_requisicoes()
    id_req = int(input("Digite o ID da requisição para excluir: "))
    conexao = conectar()
    cursor = conexao.cursor()
    cursor.execute("DELETE FROM requisicoes_vinicius WHERE id = %s", (id_req,))
    conexao.commit()
    conexao.close()
    print("🗑️ Requisição excluída com sucesso.")

# Menu principal
def menu():
    while True:
        print("\n📘 MENU PRINCIPAL")
        print("1. Cadastrar usuário")
        print("2. Login")
        print("0. Sair")
        opcao = input("Escolha uma opção: ")

        if opcao == '1':
            cadastrar_usuario()
        elif opcao == '2':
            usuario = login()
            if usuario:
                menu_usuario(usuario)
        elif opcao == '0':
            print("👋 Encerrando o sistema.")
            break
        else:
            print("❌ Opção inválida.")

# Menu após login
def menu_usuario(usuario):
    while True:
        print("\n🔧 MENU DO USUÁRIO")
        print("1. Nova requisição")
        print("2. Listar requisições")
        if usuario['tipo'] == 'operador':
            print("3. Excluir requisição")
        print("0. Logout")
        escolha = input("Escolha uma opção: ")

        if escolha == '1':
            nova_requisicao(usuario)
        elif escolha == '2':
            listar_requisicoes()
        elif escolha == '3' and usuario['tipo'] == 'operador':
            excluir_requisicao()
        elif escolha == '0':
            print("🔒 Logout realizado.")
            break
        else:
            print("❌ Opção inválida.")

# Rodar o sistema
if __name__ == "__main__":
    menu()
